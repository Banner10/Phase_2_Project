# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt   
import folium 
import seaborn as sns 
plt.style.use('seaborn')
import plotly.express as px
import scipy.stats as stats

import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import statsmodels.stats.api as sms

import plotly.express as px

# %%
df_house = pd.read_csv('kc_house_data.csv')
df_house_cleaned = pd.read_csv('house_clean.csv')

# %%
# Let's visualize the price distirubtion for all zipcodes on a map. 

zipcode_prices = df_house.groupby('zipcode')['price'].mean().reset_index().sort_values('price', ascending=False)
zipcode_prices['zipcode'] = zipcode_prices['zipcode'].astype(str)
zipcode_prices
# Out:
#    zipcode         price
# 24   98039  2.160607e+06
# 3    98004  1.355927e+06
# 25   98040  1.194230e+06
# 48   98112  1.095499e+06
# 41   98102  9.012583e+05
# ..     ...           ...
# 61   98148  2.849086e+05
# 0    98001  2.808047e+05
# 20   98032  2.512962e+05
# 64   98168  2.403284e+05
# 1    98002  2.342840e+05
#
# [70 rows x 2 columns]

# %%
plt.scatter(df_house['long'],df_house['lat'],alpha=0.05,cmap="flag")
plt.show()

# %%
df_house_1 = df_house[df_house.price < 2000000]

# %%
import plotly.express as px
fig = px.scatter(df_house_1, x='long', y='lat', color="price")
fig.show()

# %%
df_house_2 = df_house[df_house.price > 2000000]

# %%
import plotly.express as px
fig = px.scatter(df_house_2, x='long', y='lat', color="price")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-877037d03f65> in <module>()
#       1 import plotly.express as px
# ----> 2 fig = px.scatter(df_house_2, x='long', y='lat', color="price")
#       3 fig.show()
#
# NameError: name 'df_house_2' is not defined

# %%
sns.lmplot(x='sqft_living', y='price', data=df_house, scatter_kws={'s':8}, height=6)

plt.title('Size Relative to Price', size=18)
plt.ylabel('House Price', size=15)
plt.xlabel('Total Square Feet', size=15)


plt.show()

# %%
plt.figure(figsize=(16,5))

sns.lineplot(x='yr_built', y='price', data=df_house_cleaned,linewidth=1.5, color='blueviolet', ci=None)

plt.title('Average Home Price and Year Built', size=18)
plt.ylabel('Average Price', size=15)
plt.xlabel('Year', size=15)

plt.show()

# %%
groups = df_house_cleaned.groupby(['grade'])['price'].mean()
plt.figure(figsize=(10, 5))
plt.xlabel('price')
plt.title('Grade Of Construction materials and Price', size=18)
groups.plot.barh()

# %%
groups = df_house_cleaned.groupby(['bedrooms'])['price'].mean()
plt.figure(figsize=(10, 5))
plt.xlabel('price')
plt.title('Bedrooms and Price', size=18)
groups.plot.barh()

# %%
#JOINT PLOTS ON ALL DATAFRAME

sns.jointplot(x="sqft_lot", y="price", data=df_house, kind = 'reg', height = 10)
sns.jointplot(x="sqft_above", y="price", data=df_house, kind = 'reg', height = 10)
sns.jointplot(x="sqft_basement", y="price", data=df_house, kind = 'reg', height = 10)
sns.jointplot(x="sqft_living15", y="price", data=df_house, kind = 'reg', height = 10)
sns.jointplot(x="sqft_lot15", y="price", data=df_house, kind = 'reg', height = 10)
sns.jointplot(x="yr_built", y="price", data=df_house, kind = 'reg', height = 10)
sns.jointplot(x="lat", y="price", data=df_house, kind = 'reg', height = 10)
sns.jointplot(x="long", y="price", data=df_house, kind = 'reg', height = 10)
plt.show()

# %%
#JOINT PLOTS OUTLIERS REMOVED

sns.jointplot(x="sqft_lot", y="price", data=df_house_cleaned, kind = 'reg', height = 10)
sns.jointplot(x="sqft_above", y="price", data=df_house_cleaned, kind = 'reg', height = 10)
sns.jointplot(x="sqft_basement", y="price", data=df_house_cleaned, kind = 'reg', height = 10)
sns.jointplot(x="sqft_living15", y="price", data=df_house_cleaned, kind = 'reg', height = 10)
sns.jointplot(x="sqft_lot15", y="price", data=df_house_cleaned, kind = 'reg', height = 10)
sns.jointplot(x="yr_built", y="price", data=df_house_cleaned, kind = 'reg', height = 10)
sns.jointplot(x="lat", y="price", data=df_house_cleaned, kind = 'reg', height = 10)
sns.jointplot(x="long", y="price", data=df_house_cleaned, kind = 'reg', height = 10)
plt.show()

# %%
#JOINT PLOTS OUTLIERS REMOVED

sns.jointplot(x="sqft_lot", y="price", data=df_house_cleaned, kind = 'resid', height = 10)
sns.jointplot(x="sqft_above", y="price", data=df_house_cleaned, kind = 'resid', height = 10)
sns.jointplot(x="sqft_basement", y="price", data=df_house_cleaned, kind = 'resid', height = 10)
sns.jointplot(x="sqft_living15", y="price", data=df_house_cleaned, kind = 'resid', height = 10)
sns.jointplot(x="sqft_lot15", y="price", data=df_house_cleaned, kind = 'resid', height = 10)
sns.jointplot(x="yr_built", y="price", data=df_house_cleaned, kind = 'resid', height = 10)
sns.jointplot(x="lat", y="price", data=df_house_cleaned, kind = 'resid', height = 10)
sns.jointplot(x="long", y="price", data=df_house_cleaned, kind = 'resid', height = 10)
plt.show()
